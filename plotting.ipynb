# %%
epochs = range(0,20)
urdu_transferred_training = [80, 88.75, 100, 93.75, 90, 100, 100, 100, 100, 97.5]
urdu_transferred_test = [91,92,93,93,92,93,94,94,94,94]

urdu_transfer_training = [25,45,51,49,74,84,85,91.25,91.25,95]
urdu_transfer_testing = [27,34,44,62.5,79,84,80.6,78,86,79]

urdu_transfer_training_notfrozen = [31.25, 47.5, 58.75, 61.25, 73.75, 87.5, 85, 88.75, 87.5, 91.25]
urdu_transfer_testing_notfrozen = [32.2, 37.2, 45, 55.3, 75, 79.3, 80.6, 77.5, 83.1, 82.8]

urdu_scratch_training = [38.125, 61.875, 66.875, 71.25, 71.875, 77.1875, 85.3125, 84.6875, 87.1875, 86.25, 90.3125, 92.8125, 92.8125, 91.5625, 96.25 ,98.125 ,97.5 ,94.375 ,96.5625 ,98.4375]
urdu_scratch_testing = [41.25, 48.75, 67.5, 57.5, 66.25, 68.75, 67.5, 50, 73.75, 75, 71.25, 71.25, 72.5, 62.5, 77.5, 63.75, 73.75, 65, 70, 67.5]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,10))

plt.subplot(221)
plt.plot(range(0,10), urdu_transferred_training, label='Training')
plt.plot(range(0,10), urdu_transferred_test, label='Test')
plt.title('Pretrained Model Trained on Ravdess')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.ylim([0, 105])
plt.subplot(222)
plt.plot(range(0,10), urdu_transfer_training, label='Training')
plt.plot(range(0,10), urdu_transfer_testing, label='Test')
plt.title('Pretrained Model with Frozen Weights')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.ylim([0, 105])
plt.subplot(223)
plt.plot(range(0,10), urdu_transfer_training_notfrozen, label='Training')
plt.plot(range(0,10), urdu_transfer_testing_notfrozen, label='Test')
plt.title('Pretrained Model trained on Urdu')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.ylim([0, 105])
plt.subplot(224)
plt.plot(epochs, urdu_scratch_training, label='Training')
plt.plot(epochs, urdu_scratch_testing, label='Test')
plt.title('Model Trained from Scratch on Urdu')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.ylim([0, 105])
plt.tight_layout()
plt.show()
plt.savefig('fig1.pdf')

# %%
plt.figure(figsize=(10,6))

plt.plot(range(0,10), urdu_transferred_test, label='Pretrained Model Trained on Ravdess')
plt.plot(range(0,10), urdu_transfer_testing, label='Pretrained Model with Frozen Weights')
plt.plot(range(0,10), urdu_transfer_testing_notfrozen, label='Pretrained Model trained on Urdu')
plt.plot(range(0,10), urdu_scratch_testing[0:10], label='Model Trained from Scratch on Urdu')

plt.title('Comparing Testing Results for Urdu Dataset')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
plt.savefig('fig2.pdf')

# %%
import pandas as pd

data = {
    'Model': ['Pretrained Model Trained on Ravdess', 'Pretrained Model with Frozen Weights', 'Pretrained Model trained on EmoDB', 'Model Trained from Scratch on EmoDB'],
    'Final Accuracy on EmoDB (%)': [98.5, 80.6, 82.4, 55.1]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                                   Model  Final Accuracy on EmoDB (%)
# 0   Pretrained Model Trained on Ravdess                         98.5
# 1  Pretrained Model with Frozen Weights                         80.6
# 2     Pretrained Model trained on EmoDB                         82.4
# 3   Model Trained from Scratch on EmoDB                         55.1

# %%
fig, ax = plt.subplots()

ax.axis('tight')
ax.axis('off')
ax.table(cellText=df.values, colLabels=df.columns, cellLoc = 'center', loc='center')
plt.show()
plt.savefig('EmoDBtable.pdf')
